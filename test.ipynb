# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Github/DL-project')

# %cd /content/drive/MyDrive/Github/DL-project/

# %%
import numpy as np

# %%
print('Hello world')
# Out:
# Hello world

# %%
import taro

# %%
taro.yo()
# Out:
# yoooooo
